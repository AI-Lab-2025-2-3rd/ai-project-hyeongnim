# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Lab-2025-2-3rd/ai-project-hyeongnim/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80_%EB%B0%98%EB%8F%84%EC%B2%B4_%EC%9D%B4%EC%83%81%ED%83%90%EC%A7%80_%EC%B5%9C%EC%A2%85(%EC%88%98%EC%A0%95ver)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import cv2
from PIL import Image
from tqdm import tqdm
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torchvision.transforms.functional as TF
from skimage.transform import resize as sk_resize

# %%
import zipfile


with zipfile.ZipFile("/content/data.zip", 'r') as target_file:
    target_file.extractall('/content/data')

# %%
# 데이터 로딩 클래스 정의
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): csv 파일의 경로.
            transform (callable, optional): 샘플에 적용될 Optional transform.
        """
        self.df = pd.read_csv(csv_file)
        # Assuming the image paths in the CSV are relative and the images are extracted to /content/data/open/
        self.df["img_path"] = self.df["img_path"].apply(lambda x: os.path.join("/content/data/open", x))
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df["img_path"].iloc[idx]
        image = Image.open(img_path)
        if self.transform:
            image = self.transform(image)
        target = torch.tensor([0.0]).float()
        return image, target


# 이미지 전처리 및 임베딩
transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),  # NOTE: 256 x 256 resize
        transforms.CenterCrop((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ]
)

# %%
device = torch.device("cuda")
memory_bank_path = "./memory_bank/resnet18"  # memory bank를 저장할 경로

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

model.eval()
test = nn.Sequential(*list(model.children())[:-3])
model = model.to(device)

# 기호 정리:
# N: batch size
# N': memory bank size
# query: query size
# D: target_dim
# |A|: patch collection size
# |P|: patch_size


# Patchcore Implementation - https://arxiv.org/abs/2106.08265
class PatchCore(nn.Module):
    def __init__(
        self,
        backbone,
        per_memory_bank_size=4,
        memory_bank_path="./memory_bank",
        device=device,
        target_dim=384 * 3,  # |D|
        patch_size=3,  # |P|
        d=3,  # nearest
    ):
        """
        Args:
            backbone: torch.nn.Module
            per_memory_bank_size: int
            memory_bank_path: str
            device: torch.device
            target_dim: int
            patch_size: int
            d: int
        """

        super().__init__()
        self.backbone = model
        self.backbone.eval()

        self.layer2_output, self.layer3_output = None, None
        self.register_hook_for_layer2()  # register hook for layer2
        self.register_hook_for_layer3()  # register hook for layer3

        self.memory_bank = None
        self.per_memory_bank_size = per_memory_bank_size
        self.memory_bank_path = memory_bank_path
        self.device = device
        self.target_dim = target_dim
        self.average_pool = nn.AdaptiveAvgPool1d(self.target_dim)
        self.patch_size = patch_size
        self.d = d

    def register_hook_for_layer2(self):
        self.backbone.layer2.register_forward_hook(self._register_hook_for_layer2)

    def _register_hook_for_layer2(self, module, input, output):  # (B, 128, 28, 28)
        layer2_output = output
        self.layer2_output = layer2_output  # (B, 128, 28, 28)
        # self.layer2_output = None

    def register_hook_for_layer3(self):
        self.backbone.layer3.register_forward_hook(self._register_hook_for_layer3)

    def _register_hook_for_layer3(self, module, input, output):  # (B, 256, 14, 14)
        layer3_output = output
        layer3_output = nn.functional.interpolate(
            layer3_output, scale_factor=2, mode="bilinear"
        )
        self.layer3_output = layer3_output  # (B, 256, 28, 28)

    def save_memory_bank(self, train_batch, file_name):
        """
        training batch를 받아서 memory bank에 저장한다.
        """
        self.backbone(train_batch)
        path = os.path.join(self.memory_bank_path, file_name)
        new_memory = self.patch_collection(self.patch_size)
        new_memory = new_memory.reshape(-1, new_memory.shape[-1])
        torch.save(new_memory, path)

    def loader_memory_bank(self):
        """
        memory bank를 이터레이터로 불러온다.
        """
        file_list = os.listdir(self.memory_bank_path)
        file_list = [file for file in file_list if file.endswith(".pth")]
        file_list.sort()
        for file in file_list:
            path = os.path.join(self.memory_bank_path, file)
            new_memory = torch.load(path, map_location=self.device)

            yield new_memory

    def forward(self, x):
        self.backbone(x)
        query = self.patch_collection(self.patch_size)  # (N, |A|, D)
        l2 = torch.Tensor([]).to(device)
        for memory in self.loader_memory_bank():
            l2 = torch.cat((l2, self.cal_l2(query, memory)), dim=1)
            del memory

        s_ = self.get_anomaly_score(l2)
        s = self.update_anomaly_score(s_, l2, self.d)
        return s

    def get_anomaly_score(self, l2):
        """
        Args:
            l2: (query, N', |A|)
        """
        min_l2 = l2.min(dim=1).values  # (query, |A|)
        max_min_l2 = min_l2.max(dim=1).values  # (query, )
        return max_min_l2

    def update_anomaly_score(self, s_, l2: torch.Tensor, d):
        """
        Args:
            l2: (query, N', |A|)
            d = nearest
        """
        m_train = l2.min(dim=1)  # (query, |A|)
        m_test = m_train.values.max(dim=1)  # (query)
        m_for_test = l2[:, :, m_test.indices]  # (query, N')
        m_train_nearest = m_for_test.topk(k=d, dim=1).values  # (query, d)

        update_weight = 1 - (
            torch.exp(m_test.values) / torch.exp(m_train_nearest).sum(dim=1)
        )
        s = s_ * update_weight
        return s

    def cal_l2(self, query, memory_bank):
        """
        return: (query_size, memory_bank_size, |A|)
        """
        memory_bank = memory_bank.unsqueeze(1)  # (N', 1, D)
        N, D = memory_bank.shape[0], memory_bank.shape[2]
        memory_bank = memory_bank.expand(N, query.shape[1], D)  # (N', |A|, D)
        l2 = []
        for q in query:
            q = q.unsqueeze(0)  # (1, |A|, D)
            diff = memory_bank - q  # (N', |A|, D)
            l2_ = diff.square().sum(dim=2)  # (N', |A|)
            l2_ = l2_.sqrt()
            l2.append(l2_)
            del q
        l2 = torch.stack(l2, dim=0)  # (query, N', |A|)
        return l2

    def feature(self, h, w):
        """
        return: (N, C)
        """
        H, W = self.layer2_output.shape[2], self.layer2_output.shape[3]
        if not (0 <= h < H and 0 <= w < W):
            return torch.tensor([]).to(self.device)
        layer2 = self.layer2_output[:, :, h, w]  # (B, C)

        # TODO: 아래 코드
        if self.layer3_output is not None:
            layer3 = self.layer3_output[:, :, h, w]  # (B, C')
        else:
            layer3 = torch.tensor([]).to(self.device)

        feature = torch.cat((layer2, layer3), dim=1)
        return feature

    def neighborhood_features(self, h, w, patch_size):
        """
        return: (N, |P|, C) -> path_size x patch_size
        """
        features = []
        for i in range(math.floor(-patch_size / 2), math.floor(patch_size / 2)):
            for j in range(math.floor(-patch_size / 2), math.floor(patch_size / 2)):
                feature = self.feature(h + i, w + j)
                if feature.shape[0] == 0:
                    continue
                features.append(feature)
        features = torch.stack(features, dim=1)
        return features

    def patch(self, h, w, patch_size):
        """
        return: (N, D)
        """
        features = self.neighborhood_features(h, w, patch_size)
        features = features.permute(0, 2, 1)  # (N, C, |P|)
        features = features.reshape(features.shape[0], -1)  # (N, C X |P|)
        features = self.average_pool(features)  # (N, target_dim) = (N, D)
        return features

    def patch_collection(self, patch_size):
        """
        return: (N, |A|, D)
        """
        H, W = self.layer2_output.shape[2], self.layer2_output.shape[3]

        patch_collection = []
        # average pooling으로 나눌 수 있게 중심만 고려한다.
        for h in range(math.ceil(patch_size / 2), H - math.ceil(patch_size / 2)):
            for w in range(math.ceil(patch_size / 2), W - math.ceil(patch_size / 2)):
                patch = self.patch(h, w, patch_size)
                patch_collection.append(patch)
        patch_collection = torch.stack(patch_collection, dim=1)
        return patch_collection
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 176MB/s]

# %%
params = {
    "patch_size": 5,
    "per_memory_bank_size": 1,
    "d": 2,
    "target_dim": 1920,
}

# %%
k = 13  # Train data를 몇 개씩 slice할 것인지

# %%
# Threshold 구하기
data = pd.read_csv("/content/data/open/train.csv")
sum = 0.0
m = 213 // k


def save2(batch_size=1, config=dict()):  # Threshold 구하는 데 필요한 save 함수
    # memory_bank_path 폴더 초기화
    if os.path.exists(memory_bank_path):
        for file in os.listdir(memory_bank_path):
            os.remove(os.path.join(memory_bank_path, file))
    else:
        os.makedirs(memory_bank_path)

    patch_core = PatchCore(model, memory_bank_path=memory_bank_path, **config)
    train_data = CustomDataset(csv_file="./train2.csv", transform=transform)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=False)

    for idx, x in enumerate(tqdm(train_loader)):
        x = x[0].to(device)
        patch_core.save_memory_bank(x, f"memory_bank_{batch_size*idx}.pth")


for i in range(m):
    j = i * k
    validation_indices = range(j, j + k)  # k개씩 슬라이싱
    validation_idx = data.loc[validation_indices]
    train_idx = data.drop(validation_indices)

    train_idx.to_csv("./train2.csv", index=False)
    validation_idx.to_csv("./validation.csv", index=False)

    save2(batch_size=1, config=params)

    patch_core = PatchCore(model, memory_bank_path=memory_bank_path, **params)
    test_data = CustomDataset(csv_file="./validation.csv", transform=transform)
    test_loader = DataLoader(test_data, batch_size=1, shuffle=False)
    anomaly_score = torch.tensor([], device=device)
    with torch.no_grad():
        for idx, x in tqdm(enumerate(test_loader), desc="query"):
            x = x[0].to(device)
            l2 = patch_core.forward(x)

            print(f"l2: {l2}")

            anomaly_score = torch.cat([anomaly_score, l2], dim=0)
            anomaly_score_sorted_idx = anomaly_score.sort(descending=True).indices

    anomaly_score = anomaly_score.cpu()

    max_value, max_index = torch.max(anomaly_score, 0)
    print(f"{i+1}th slice max value : {max_value.item():.4f} \n")
    sum += max_value.item()
# Out:
# 100%|██████████| 200/200 [02:26<00:00,  1.36it/s]
# query: 12it [01:38,  8.21s/it]
# l2: tensor([[3.9808]], device='cuda:0')
# query: 13it [01:46,  8.22s/it]
# l2: tensor([[4.0213]], device='cuda:0')
# 15th slice max value : 5.6317
# 100%|██████████| 200/200 [02:22<00:00,  1.40it/s]
# query: 1it [00:08,  8.15s/it]
# l2: tensor([[4.1284]], device='cuda:0')
# query: 2it [00:16,  8.15s/it]
# l2: tensor([[4.1318]], device='cuda:0')
# query: 3it [00:24,  8.16s/it]
# l2: tensor([[3.9975]], device='cuda:0')
# query: 4it [00:32,  8.17s/it]
# l2: tensor([[4.6501]], device='cuda:0')
# query: 5it [00:40,  8.18s/it]
# l2: tensor([[4.3513]], device='cuda:0')
# query: 6it [00:49,  8.18s/it]
# l2: tensor([[4.1222]], device='cuda:0')
# query: 7it [00:57,  8.19s/it]
# l2: tensor([[4.3457]], device='cuda:0')
# query: 8it [01:05,  8.19s/it]
# l2: tensor([[4.1172]], device='cuda:0')
# query: 9it [01:13,  8.19s/it]
# l2: tensor([[4.4425]], device='cuda:0')
# query: 10it [01:21,  8.19s/it]
# l2: tensor([[4.5016]], device='cuda:0')
# query: 11it [01:29,  8.19s/it]
# l2: tensor([[3.9477]], device='cuda:0')
# query: 12it [01:38,  8.18s/it]
# l2: tensor([[4.4261]], device='cuda:0')
# query: 13it [01:46,  8.20s/it]
# l2: tensor([[3.7177]], device='cuda:0')
# 16th slice max value : 4.6501

# %%
Threshold = sum / m  # max_value들의 평균
print(f"Threshold of PatchCore(Size=5) : {Threshold}")
# Out:
# Threshold of PatchCore(Size=5) : 5.203663945198059

# %%
def save(batch_size=1, config=dict()):  # Inference에 필요한 save 함수
    # memory_bank_path 폴더 초기화
    if os.path.exists(memory_bank_path):
        for file in os.listdir(memory_bank_path):
            os.remove(os.path.join(memory_bank_path, file))
    else:
        os.makedirs(memory_bank_path)

    patch_core = PatchCore(model, memory_bank_path=memory_bank_path, **config)
    train_data = CustomDataset(csv_file="/content/data/open/train.csv", transform=transform)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=False)

    for idx, x in enumerate(tqdm(train_loader)):
        x = x[0].to(device)
        patch_core.save_memory_bank(x, f"memory_bank_{batch_size*idx}.pth")

# %%
save(batch_size=1, config=params)

patch_core = PatchCore(model, memory_bank_path=memory_bank_path, **params)

test_data = CustomDataset(csv_file="/content/data/open/test.csv", transform=transform)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)
anomaly_score = torch.tensor([], device=device)
with torch.no_grad():
    for idx, x in tqdm(enumerate(test_loader), desc="query"):
        x = x[0].to(device)
        l2 = patch_core.forward(x)

        # for i in range(l2.shape[0]):
        #     wandb.log({"l2": l2[i].item()})
        print(f"l2: {l2}")

        anomaly_score = torch.cat([anomaly_score, l2], dim=0)
        anomaly_score_sorted_idx = anomaly_score.sort(descending=True).indices

anomaly_score = anomaly_score.cpu()
plt.plot(anomaly_score)
plt.show()
# Out:
# 100%|██████████| 213/213 [02:33<00:00,  1.39it/s]
# query: 1it [00:08,  8.67s/it]
# l2: tensor([[5.1689]], device='cuda:0')
# Multi-Size Patchcore, patch_size = 20

# %%
device2 = torch.device("cuda")
memory_bank_path2 = "./memory_bank/resnet18_2"  # 두 번째 모델의 memory bank 저장 경로

# %%
model2 = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model2.eval()
test2 = nn.Sequential(*list(model2.children())[:-3])
model2 = model2.to(device2)

# %%
params2 = {
    "patch_size": 20,
    "per_memory_bank_size": 1,
    "d": 2,
    "target_dim": 1920,
}

# %%
k2 = 30  # Train data를 몇 개씩 slice할 것인지

# %%
# Threshold 구하기 (두 번째 모델용)
data2 = pd.read_csv("/content/data/open/train.csv")
sum2 = 0.0
m2 = 213 // k2


def save22(batch_size=1, config=dict()):  # Threshold 구하는 데 필요한 save 함수 (ver2)
    # memory_bank_path2 폴더 초기화
    if os.path.exists(memory_bank_path2):
        for file in os.listdir(memory_bank_path2):
            os.remove(os.path.join(memory_bank_path2, file))
    else:
        os.makedirs(memory_bank_path2)

    patch_core2 = PatchCore(model2, memory_bank_path=memory_bank_path2, **config)
    train_data2 = CustomDataset(csv_file="./train22.csv", transform=transform)
    train_loader2 = DataLoader(train_data2, batch_size=batch_size, shuffle=False)

    for idx2, x2 in enumerate(tqdm(train_loader2)):
        x2 = x2[0].to(device2)
        patch_core2.save_memory_bank(x2, f"memory_bank2_{batch_size*idx2}.pth")


for i2 in range(m2):
    j2 = i2 * k2
    validation_indices2 = range(j2, j2 + k2)  # k개씩 슬라이싱
    validation_idx2 = data2.loc[validation_indices2]
    train_idx2 = data2.drop(validation_indices2)

    train_idx2.to_csv("./train22.csv", index=False)
    validation_idx2.to_csv("./validation2.csv", index=False)

    save22(batch_size=1, config=params2)

    patch_core2 = PatchCore(model2, memory_bank_path=memory_bank_path2, **params2)
    test_data2 = CustomDataset(csv_file="./validation2.csv", transform=transform)
    test_loader2 = DataLoader(test_data2, batch_size=1, shuffle=False)
    anomaly_score2 = torch.tensor([], device=device2)
    with torch.no_grad():
        for idx2, x2 in tqdm(enumerate(test_loader2), desc="query2"):
            x2 = x2[0].to(device2)
            l22 = patch_core2.forward(x2)

            print(f"l22: {l22}")

            anomaly_score2 = torch.cat([anomaly_score2, l22], dim=0)
            anomaly_score_sorted_idx2 = anomaly_score2.sort(descending=True).indices

    anomaly_score2 = anomaly_score2.cpu()

    max_value2, max_index2 = torch.max(anomaly_score2, 0)
    print(f"{i2+1}th slice max value : {max_value2.item():.4f} \n")
    sum2 += max_value2.item()
# Out:
# 100%|██████████| 183/183 [04:07<00:00,  1.35s/it]
# query2: 1it [00:01,  1.03s/it]
# l22: tensor([[1.5972]], device='cuda:0')
# query2: 2it [00:02,  1.18s/it]
# l22: tensor([[1.6009]], device='cuda:0')
# query2: 3it [00:03,  1.31s/it]
# l22: tensor([[1.4332]], device='cuda:0')
# query2: 4it [00:04,  1.20s/it]
# l22: tensor([[1.3689]], device='cuda:0')
# query2: 5it [00:05,  1.15s/it]
# l22: tensor([[1.6081]], device='cuda:0')
# query2: 6it [00:06,  1.12s/it]
# l22: tensor([[1.7926]], device='cuda:0')
# query2: 7it [00:07,  1.10s/it]
# l22: tensor([[1.4215]], device='cuda:0')
# query2: 8it [00:09,  1.08s/it]
# l22: tensor([[1.6530]], device='cuda:0')
# query2: 9it [00:10,  1.07s/it]
# l22: tensor([[1.4419]], device='cuda:0')
# query2: 10it [00:11,  1.06s/it]
# l22: tensor([[1.3477]], device='cuda:0')
# query2: 11it [00:12,  1.06s/it]
# l22: tensor([[1.6445]], device='cuda:0')
# query2: 12it [00:13,  1.06s/it]
# l22: tensor([[1.3621]], device='cuda:0')
# query2: 13it [00:14,  1.14s/it]
# l22: tensor([[1.4832]], device='cuda:0')
# query2: 14it [00:15,  1.22s/it]
# l22: tensor([[1.5785]], device='cuda:0')
# query2: 15it [00:17,  1.17s/it]
# l22: tensor([[1.5368]], device='cuda:0')
# query2: 16it [00:18,  1.14s/it]
# l22: tensor([[1.5658]], device='cuda:0')
# query2: 17it [00:19,  1.12s/it]
# l22: tensor([[1.7611]], device='cuda:0')
# query2: 18it [00:20,  1.09s/it]
# l22: tensor([[1.8474]], device='cuda:0')
# query2: 19it [00:21,  1.08s/it]
# l22: tensor([[1.4587]], device='cuda:0')
# query2: 20it [00:22,  1.07s/it]
# l22: tensor([[1.3065]], device='cuda:0')
# query2: 21it [00:23,  1.06s/it]
# l22: tensor([[1.7485]], device='cuda:0')
# query2: 22it [00:24,  1.05s/it]
# l22: tensor([[1.4627]], device='cuda:0')
# query2: 23it [00:25,  1.05s/it]
# l22: tensor([[1.5703]], device='cuda:0')
# query2: 24it [00:26,  1.15s/it]
# l22: tensor([[1.6039]], device='cuda:0')
# query2: 25it [00:28,  1.22s/it]
# l22: tensor([[1.5377]], device='cuda:0')
# query2: 26it [00:29,  1.16s/it]
# l22: tensor([[1.4545]], device='cuda:0')
# query2: 27it [00:30,  1.12s/it]
# l22: tensor([[1.4220]], device='cuda:0')
# query2: 28it [00:31,  1.10s/it]
# l22: tensor([[1.5478]], device='cuda:0')
# query2: 29it [00:32,  1.08s/it]
# l22: tensor([[1.3843]], device='cuda:0')
# query2: 30it [00:33,  1.11s/it]
# l22: tensor([[1.3877]], device='cuda:0')
# 1th slice max value : 1.8474
# 100%|██████████| 183/183 [04:09<00:00,  1.36s/it]
# query2: 1it [00:01,  1.04s/it]
# l22: tensor([[1.6518]], device='cuda:0')
# query2: 2it [00:02,  1.04s/it]
# l22: tensor([[1.3049]], device='cuda:0')
# query2: 3it [00:03,  1.05s/it]
# l22: tensor([[1.8599]], device='cuda:0')
# query2: 4it [00:04,  1.05s/it]
# l22: tensor([[1.7172]], device='cuda:0')
# query2: 5it [00:05,  1.05s/it]
# l22: tensor([[1.3520]], device='cuda:0')
# query2: 6it [00:06,  1.05s/it]
# l22: tensor([[1.5817]], device='cuda:0')
# query2: 7it [00:07,  1.04s/it]
# l22: tensor([[1.6700]], device='cuda:0')
# query2: 8it [00:08,  1.14s/it]
# l22: tensor([[1.5606]], device='cuda:0')
# query2: 9it [00:10,  1.22s/it]
# l22: tensor([[1.5090]], device='cuda:0')
# query2: 10it [00:11,  1.16s/it]
# l22: tensor([[1.5161]], device='cuda:0')
# query2: 11it [00:12,  1.12s/it]
# l22: tensor([[1.5646]], device='cuda:0')
# query2: 12it [00:13,  1.10s/it]
# l22: tensor([[1.4861]], device='cuda:0')
# query2: 13it [00:14,  1.09s/it]
# l22: tensor([[1.4478]], device='cuda:0')
# query2: 14it [00:15,  1.07s/it]
# l22: tensor([[1.4619]], device='cuda:0')
# query2: 15it [00:16,  1.06s/it]
# l22: tensor([[1.6149]], device='cuda:0')
# query2: 16it [00:17,  1.06s/it]
# l22: tensor([[1.5287]], device='cuda:0')
# query2: 17it [00:18,  1.05s/it]
# l22: tensor([[1.4541]], device='cuda:0')
# query2: 18it [00:19,  1.05s/it]
# l22: tensor([[1.3903]], device='cuda:0')
# query2: 19it [00:20,  1.15s/it]
# l22: tensor([[1.5617]], device='cuda:0')
# query2: 20it [00:22,  1.22s/it]
# l22: tensor([[1.3957]], device='cuda:0')
# query2: 21it [00:23,  1.17s/it]
# l22: tensor([[1.5247]], device='cuda:0')
# query2: 22it [00:24,  1.14s/it]
# l22: tensor([[1.4405]], device='cuda:0')
# query2: 23it [00:25,  1.11s/it]
# l22: tensor([[1.2862]], device='cuda:0')
# query2: 24it [00:26,  1.09s/it]
# l22: tensor([[1.4653]], device='cuda:0')
# query2: 25it [00:27,  1.08s/it]
# l22: tensor([[1.4829]], device='cuda:0')
# query2: 26it [00:28,  1.08s/it]
# l22: tensor([[1.5789]], device='cuda:0')
# query2: 27it [00:29,  1.07s/it]
# l22: tensor([[1.7651]], device='cuda:0')
# query2: 28it [00:30,  1.06s/it]
# l22: tensor([[1.5878]], device='cuda:0')
# query2: 29it [00:31,  1.05s/it]
# l22: tensor([[1.4398]], device='cuda:0')
# query2: 30it [00:33,  1.10s/it]
# l22: tensor([[1.8703]], device='cuda:0')
# 2th slice max value : 1.8703
# 100%|██████████| 183/183 [04:08<00:00,  1.36s/it]
# query2: 1it [00:01,  1.04s/it]
# l22: tensor([[1.6817]], device='cuda:0')
# query2: 2it [00:02,  1.05s/it]
# l22: tensor([[1.2419]], device='cuda:0')
# query2: 3it [00:03,  1.20s/it]
# l22: tensor([[1.4347]], device='cuda:0')
# query2: 4it [00:04,  1.27s/it]
# l22: tensor([[1.6160]], device='cuda:0')
# query2: 5it [00:05,  1.19s/it]
# l22: tensor([[1.4854]], device='cuda:0')
# query2: 6it [00:06,  1.14s/it]
# l22: tensor([[1.4764]], device='cuda:0')
# query2: 7it [00:07,  1.11s/it]
# l22: tensor([[1.5051]], device='cuda:0')
# query2: 8it [00:09,  1.10s/it]
# l22: tensor([[1.5623]], device='cuda:0')
# query2: 9it [00:10,  1.09s/it]
# l22: tensor([[1.5614]], device='cuda:0')
# query2: 10it [00:11,  1.08s/it]
# l22: tensor([[1.4421]], device='cuda:0')
# query2: 11it [00:12,  1.07s/it]
# l22: tensor([[1.7142]], device='cuda:0')
# query2: 12it [00:13,  1.06s/it]
# l22: tensor([[1.4257]], device='cuda:0')
# query2: 13it [00:14,  1.05s/it]
# l22: tensor([[1.4484]], device='cuda:0')
# query2: 14it [00:15,  1.17s/it]
# l22: tensor([[1.5348]], device='cuda:0')
# query2: 15it [00:17,  1.21s/it]
# l22: tensor([[1.4937]], device='cuda:0')
# query2: 16it [00:18,  1.17s/it]
# l22: tensor([[1.5220]], device='cuda:0')
# query2: 17it [00:19,  1.13s/it]
# l22: tensor([[1.7624]], device='cuda:0')
# query2: 18it [00:20,  1.11s/it]
# l22: tensor([[1.6656]], device='cuda:0')
# query2: 19it [00:21,  1.09s/it]
# l22: tensor([[1.4223]], device='cuda:0')
# query2: 20it [00:22,  1.08s/it]
# l22: tensor([[1.7875]], device='cuda:0')
# query2: 21it [00:23,  1.07s/it]
# l22: tensor([[1.7564]], device='cuda:0')
# query2: 22it [00:24,  1.07s/it]
# l22: tensor([[1.4626]], device='cuda:0')
# query2: 23it [00:25,  1.06s/it]
# l22: tensor([[1.4986]], device='cuda:0')
# query2: 24it [00:26,  1.06s/it]
# l22: tensor([[1.6505]], device='cuda:0')
# query2: 25it [00:28,  1.19s/it]
# l22: tensor([[1.6233]], device='cuda:0')
# query2: 26it [00:29,  1.20s/it]
# l22: tensor([[1.5438]], device='cuda:0')
# query2: 27it [00:30,  1.16s/it]
# l22: tensor([[1.6086]], device='cuda:0')
# query2: 28it [00:31,  1.12s/it]
# l22: tensor([[1.4705]], device='cuda:0')
# query2: 29it [00:32,  1.10s/it]
# l22: tensor([[1.4303]], device='cuda:0')
# query2: 30it [00:33,  1.12s/it]
# l22: tensor([[1.4887]], device='cuda:0')
# 3th slice max value : 1.7875
# 100%|██████████| 183/183 [04:09<00:00,  1.36s/it]
# query2: 1it [00:01,  1.05s/it]
# l22: tensor([[1.4055]], device='cuda:0')
# query2: 2it [00:02,  1.05s/it]
# l22: tensor([[1.4447]], device='cuda:0')
# query2: 3it [00:03,  1.05s/it]
# l22: tensor([[1.5820]], device='cuda:0')
# query2: 4it [00:04,  1.04s/it]
# l22: tensor([[2.5873]], device='cuda:0')
# query2: 5it [00:05,  1.04s/it]
# l22: tensor([[1.4461]], device='cuda:0')
# query2: 6it [00:06,  1.05s/it]
# l22: tensor([[1.5105]], device='cuda:0')
# query2: 7it [00:07,  1.04s/it]
# l22: tensor([[1.6732]], device='cuda:0')
# query2: 8it [00:08,  1.09s/it]
# l22: tensor([[1.6388]], device='cuda:0')
# query2: 9it [00:09,  1.22s/it]
# l22: tensor([[1.6625]], device='cuda:0')
# query2: 10it [00:11,  1.18s/it]
# l22: tensor([[1.4143]], device='cuda:0')
# query2: 11it [00:12,  1.14s/it]
# l22: tensor([[1.7016]], device='cuda:0')
# query2: 12it [00:13,  1.11s/it]
# l22: tensor([[1.6064]], device='cuda:0')
# query2: 13it [00:14,  1.10s/it]
# l22: tensor([[1.6306]], device='cuda:0')
# query2: 14it [00:15,  1.08s/it]
# l22: tensor([[1.2859]], device='cuda:0')
# query2: 15it [00:16,  1.07s/it]
# l22: tensor([[1.4340]], device='cuda:0')
# query2: 16it [00:17,  1.06s/it]
# l22: tensor([[1.6250]], device='cuda:0')
# query2: 17it [00:18,  1.06s/it]
# l22: tensor([[1.3781]], device='cuda:0')
# query2: 18it [00:19,  1.06s/it]
# l22: tensor([[1.4768]], device='cuda:0')
# query2: 19it [00:20,  1.11s/it]
# l22: tensor([[1.5338]], device='cuda:0')
# query2: 20it [00:22,  1.24s/it]
# l22: tensor([[1.5159]], device='cuda:0')
# query2: 21it [00:23,  1.19s/it]
# l22: tensor([[1.5410]], device='cuda:0')
# query2: 22it [00:24,  1.14s/it]
# l22: tensor([[1.4946]], device='cuda:0')
# query2: 23it [00:25,  1.12s/it]
# l22: tensor([[1.4450]], device='cuda:0')
# query2: 24it [00:26,  1.10s/it]
# l22: tensor([[1.6655]], device='cuda:0')
# query2: 25it [00:27,  1.08s/it]
# l22: tensor([[1.3080]], device='cuda:0')
# query2: 26it [00:28,  1.07s/it]
# l22: tensor([[1.6061]], device='cuda:0')
# query2: 27it [00:29,  1.06s/it]
# l22: tensor([[1.7669]], device='cuda:0')
# query2: 28it [00:30,  1.06s/it]
# l22: tensor([[1.3212]], device='cuda:0')
# query2: 29it [00:31,  1.05s/it]
# l22: tensor([[1.5303]], device='cuda:0')
# query2: 30it [00:32,  1.10s/it]
# l22: tensor([[1.4854]], device='cuda:0')
# 4th slice max value : 2.5873
# 100%|██████████| 183/183 [04:09<00:00,  1.37s/it]
# query2: 1it [00:01,  1.05s/it]
# l22: tensor([[1.5605]], device='cuda:0')
# query2: 2it [00:02,  1.10s/it]
# l22: tensor([[1.5090]], device='cuda:0')
# query2: 3it [00:03,  1.27s/it]
# l22: tensor([[1.4946]], device='cuda:0')
# query2: 4it [00:04,  1.22s/it]
# l22: tensor([[1.4845]], device='cuda:0')
# query2: 5it [00:05,  1.16s/it]
# l22: tensor([[1.4079]], device='cuda:0')
# query2: 6it [00:06,  1.12s/it]
# l22: tensor([[1.4828]], device='cuda:0')
# query2: 7it [00:07,  1.10s/it]
# l22: tensor([[1.6017]], device='cuda:0')
# query2: 8it [00:09,  1.09s/it]
# l22: tensor([[1.5206]], device='cuda:0')
# query2: 9it [00:10,  1.08s/it]
# l22: tensor([[1.5917]], device='cuda:0')
# query2: 10it [00:11,  1.07s/it]
# l22: tensor([[1.5905]], device='cuda:0')
# query2: 11it [00:12,  1.07s/it]
# l22: tensor([[1.4324]], device='cuda:0')
# query2: 12it [00:13,  1.06s/it]
# l22: tensor([[1.5038]], device='cuda:0')
# query2: 13it [00:14,  1.11s/it]
# l22: tensor([[1.7000]], device='cuda:0')
# query2: 14it [00:16,  1.24s/it]
# l22: tensor([[1.7586]], device='cuda:0')
# query2: 15it [00:17,  1.19s/it]
# l22: tensor([[2.2274]], device='cuda:0')
# query2: 16it [00:18,  1.15s/it]
# l22: tensor([[1.5875]], device='cuda:0')
# query2: 17it [00:19,  1.13s/it]
# l22: tensor([[1.3942]], device='cuda:0')
# query2: 18it [00:20,  1.11s/it]
# l22: tensor([[1.4712]], device='cuda:0')
# query2: 19it [00:21,  1.09s/it]
# l22: tensor([[1.8003]], device='cuda:0')
# query2: 20it [00:22,  1.09s/it]
# l22: tensor([[1.4830]], device='cuda:0')
# query2: 21it [00:23,  1.08s/it]
# l22: tensor([[1.5027]], device='cuda:0')
# query2: 22it [00:24,  1.07s/it]
# l22: tensor([[1.3957]], device='cuda:0')
# query2: 23it [00:25,  1.06s/it]
# l22: tensor([[1.5262]], device='cuda:0')
# query2: 24it [00:26,  1.13s/it]
# l22: tensor([[1.6536]], device='cuda:0')
# query2: 25it [00:28,  1.23s/it]
# l22: tensor([[1.4387]], device='cuda:0')
# query2: 26it [00:29,  1.17s/it]
# l22: tensor([[1.3694]], device='cuda:0')
# query2: 27it [00:30,  1.13s/it]
# l22: tensor([[1.4373]], device='cuda:0')
# query2: 28it [00:31,  1.11s/it]
# l22: tensor([[1.3695]], device='cuda:0')
# query2: 29it [00:32,  1.09s/it]
# l22: tensor([[1.6178]], device='cuda:0')
# query2: 30it [00:33,  1.12s/it]
# l22: tensor([[1.4856]], device='cuda:0')
# 5th slice max value : 2.2274
# 100%|██████████| 183/183 [04:09<00:00,  1.36s/it]
# query2: 1it [00:01,  1.04s/it]
# l22: tensor([[1.3347]], device='cuda:0')
# query2: 2it [00:02,  1.05s/it]
# l22: tensor([[1.5707]], device='cuda:0')
# query2: 3it [00:03,  1.04s/it]
# l22: tensor([[1.4750]], device='cuda:0')
# query2: 4it [00:04,  1.04s/it]
# l22: tensor([[1.3197]], device='cuda:0')
# query2: 5it [00:05,  1.04s/it]
# l22: tensor([[1.4428]], device='cuda:0')
# query2: 6it [00:06,  1.04s/it]
# l22: tensor([[1.6306]], device='cuda:0')
# query2: 7it [00:07,  1.04s/it]
# l22: tensor([[1.6062]], device='cuda:0')
# query2: 8it [00:08,  1.11s/it]
# l22: tensor([[2.1508]], device='cuda:0')
# query2: 9it [00:10,  1.23s/it]
# l22: tensor([[1.3552]], device='cuda:0')
# query2: 10it [00:11,  1.18s/it]
# l22: tensor([[1.5537]], device='cuda:0')
# query2: 11it [00:12,  1.14s/it]
# l22: tensor([[1.6810]], device='cuda:0')
# query2: 12it [00:13,  1.12s/it]
# l22: tensor([[1.3741]], device='cuda:0')
# query2: 13it [00:14,  1.10s/it]
# l22: tensor([[1.3801]], device='cuda:0')
# query2: 14it [00:15,  1.09s/it]
# l22: tensor([[1.5159]], device='cuda:0')
# query2: 15it [00:16,  1.07s/it]
# l22: tensor([[1.4975]], device='cuda:0')
# query2: 16it [00:17,  1.06s/it]
# l22: tensor([[1.2401]], device='cuda:0')
# query2: 17it [00:18,  1.06s/it]
# l22: tensor([[1.4579]], device='cuda:0')
# query2: 18it [00:19,  1.06s/it]
# l22: tensor([[1.3566]], device='cuda:0')
# query2: 19it [00:20,  1.15s/it]
# l22: tensor([[1.4701]], device='cuda:0')
# query2: 20it [00:22,  1.22s/it]
# l22: tensor([[1.5296]], device='cuda:0')
# query2: 21it [00:23,  1.17s/it]
# l22: tensor([[1.4345]], device='cuda:0')
# query2: 22it [00:24,  1.13s/it]
# l22: tensor([[1.6618]], device='cuda:0')
# query2: 23it [00:25,  1.10s/it]
# l22: tensor([[1.6011]], device='cuda:0')
# query2: 24it [00:26,  1.08s/it]
# l22: tensor([[1.8219]], device='cuda:0')
# query2: 25it [00:27,  1.07s/it]
# l22: tensor([[1.6307]], device='cuda:0')
# query2: 26it [00:28,  1.07s/it]
# l22: tensor([[1.4809]], device='cuda:0')
# query2: 27it [00:29,  1.07s/it]
# l22: tensor([[1.7310]], device='cuda:0')
# query2: 28it [00:30,  1.06s/it]
# l22: tensor([[1.3911]], device='cuda:0')
# query2: 29it [00:31,  1.06s/it]
# l22: tensor([[1.4140]], device='cuda:0')
# query2: 30it [00:33,  1.11s/it]
# l22: tensor([[1.3734]], device='cuda:0')
# 6th slice max value : 2.1508
# 100%|██████████| 183/183 [04:08<00:00,  1.36s/it]
# query2: 1it [00:01,  1.05s/it]
# l22: tensor([[1.4226]], device='cuda:0')
# query2: 2it [00:02,  1.07s/it]
# l22: tensor([[1.5732]], device='cuda:0')
# query2: 3it [00:03,  1.19s/it]
# l22: tensor([[1.4927]], device='cuda:0')
# query2: 4it [00:04,  1.29s/it]
# l22: tensor([[1.8122]], device='cuda:0')
# query2: 5it [00:05,  1.20s/it]
# l22: tensor([[1.4204]], device='cuda:0')
# query2: 6it [00:07,  1.15s/it]
# l22: tensor([[1.4604]], device='cuda:0')
# query2: 7it [00:08,  1.12s/it]
# l22: tensor([[1.5990]], device='cuda:0')
# query2: 8it [00:09,  1.09s/it]
# l22: tensor([[1.8686]], device='cuda:0')
# query2: 9it [00:10,  1.08s/it]
# l22: tensor([[1.5270]], device='cuda:0')
# query2: 10it [00:11,  1.06s/it]
# l22: tensor([[1.5501]], device='cuda:0')
# query2: 11it [00:12,  1.06s/it]
# l22: tensor([[1.5556]], device='cuda:0')
# query2: 12it [00:13,  1.06s/it]
# l22: tensor([[1.6052]], device='cuda:0')
# query2: 13it [00:14,  1.05s/it]
# l22: tensor([[1.5230]], device='cuda:0')
# query2: 14it [00:15,  1.16s/it]
# l22: tensor([[1.3632]], device='cuda:0')
# query2: 15it [00:17,  1.22s/it]
# l22: tensor([[1.5461]], device='cuda:0')
# query2: 16it [00:18,  1.17s/it]
# l22: tensor([[1.4387]], device='cuda:0')
# query2: 17it [00:19,  1.13s/it]
# l22: tensor([[1.6295]], device='cuda:0')
# query2: 18it [00:20,  1.10s/it]
# l22: tensor([[1.4481]], device='cuda:0')
# query2: 19it [00:21,  1.08s/it]
# l22: tensor([[1.6856]], device='cuda:0')
# query2: 20it [00:22,  1.07s/it]
# l22: tensor([[1.5022]], device='cuda:0')
# query2: 21it [00:23,  1.06s/it]
# l22: tensor([[1.6719]], device='cuda:0')
# query2: 22it [00:24,  1.06s/it]
# l22: tensor([[1.5225]], device='cuda:0')
# query2: 23it [00:25,  1.06s/it]
# l22: tensor([[1.5063]], device='cuda:0')
# query2: 24it [00:26,  1.05s/it]
# l22: tensor([[1.6229]], device='cuda:0')
# query2: 25it [00:27,  1.16s/it]
# l22: tensor([[1.5590]], device='cuda:0')
# query2: 26it [00:29,  1.21s/it]
# l22: tensor([[1.3210]], device='cuda:0')
# query2: 27it [00:30,  1.16s/it]
# l22: tensor([[1.5797]], device='cuda:0')
# query2: 28it [00:31,  1.12s/it]
# l22: tensor([[1.3987]], device='cuda:0')
# query2: 29it [00:32,  1.11s/it]
# l22: tensor([[1.5460]], device='cuda:0')
# query2: 30it [00:33,  1.11s/it]
# l22: tensor([[1.5088]], device='cuda:0')
# 7th slice max value : 1.8686

# %%
Threshold2 = sum2 / m2  # max_value들의 평균
print(f"Threshold of PatchCore(Size=20) : {Threshold2}")
# Out:
# Threshold of PatchCore(Size=20) : 2.048465779849461

# %%
def save2(batch_size=1, config=dict()):  # Inference에 필요한 save 함수 (두 번째 모델용)
    # memory_bank_path2 폴더 초기화
    if os.path.exists(memory_bank_path2):
        for file in os.listdir(memory_bank_path2):
            os.remove(os.path.join(memory_bank_path2, file))
    else:
        os.makedirs(memory_bank_path2)

    patch_core2 = PatchCore(model2, memory_bank_path=memory_bank_path2, **config)
    train_data2 = CustomDataset(csv_file="/content/data/open/train.csv", transform=transform)
    train_loader2 = DataLoader(train_data2, batch_size=batch_size, shuffle=False)

    for idx2, x2 in enumerate(tqdm(train_loader2)):
        x2 = x2[0].to(device2)
        patch_core2.save_memory_bank(x2, f"memory_bank2_{batch_size*idx2}.pth")

# %%
save2(batch_size=1, config=params2)

patch_core2 = PatchCore(model2, memory_bank_path=memory_bank_path2, **params2)

test_data2 = CustomDataset(csv_file="/content/data/open/test.csv", transform=transform)
test_loader2 = DataLoader(test_data2, batch_size=1, shuffle=False)
anomaly_score2 = torch.tensor([], device=device2)

with torch.no_grad():
    for idx2, x2 in tqdm(enumerate(test_loader2), desc="query2"):
        x2 = x2[0].to(device2)
        l22 = patch_core2.forward(x2)

        # for i2 in range(l22.shape[0]):
        #     wandb.log({"l22": l22[i2].item()})
        print(f"l22: {l22}")

        anomaly_score2 = torch.cat([anomaly_score2, l22], dim=0)
        anomaly_score_sorted_idx2 = anomaly_score2.sort(descending=True).indices

anomaly_score2 = anomaly_score2.cpu()
plt.plot(anomaly_score2)
plt.show()
# Out:
# 100%|██████████| 213/213 [04:48<00:00,  1.35s/it]
# query2: 1it [00:01,  1.07s/it]
# l22: tensor([[1.7377]], device='cuda:0')
# query2: 2it [00:02,  1.08s/it]
# l22: tensor([[1.7793]], device='cuda:0')
# query2: 3it [00:03,  1.07s/it]
# l22: tensor([[1.4456]], device='cuda:0')
# query2: 4it [00:04,  1.07s/it]
# l22: tensor([[1.4081]], device='cuda:0')
# query2: 5it [00:05,  1.13s/it]
# l22: tensor([[1.6056]], device='cuda:0')
# query2: 6it [00:07,  1.27s/it]
# l22: tensor([[1.6274]], device='cuda:0')
# query2: 7it [00:08,  1.20s/it]
# l22: tensor([[1.7060]], device='cuda:0')
# query2: 8it [00:09,  1.16s/it]
# l22: tensor([[1.3879]], device='cuda:0')
# query2: 9it [00:10,  1.13s/it]
# l22: tensor([[1.5173]], device='cuda:0')
# query2: 10it [00:11,  1.12s/it]
# l22: tensor([[2.3868]], device='cuda:0')
# query2: 11it [00:12,  1.11s/it]
# l22: tensor([[1.4405]], device='cuda:0')
# query2: 12it [00:13,  1.10s/it]
# l22: tensor([[1.6212]], device='cuda:0')
# query2: 13it [00:14,  1.09s/it]
# l22: tensor([[1.5341]], device='cuda:0')
# query2: 14it [00:15,  1.08s/it]
# l22: tensor([[1.4209]], device='cuda:0')
# query2: 15it [00:16,  1.08s/it]
# l22: tensor([[1.7085]], device='cuda:0')
# query2: 16it [00:18,  1.18s/it]
# l22: tensor([[1.7184]], device='cuda:0')
# query2: 17it [00:19,  1.24s/it]
# l22: tensor([[1.4714]], device='cuda:0')
# query2: 18it [00:20,  1.18s/it]
# l22: tensor([[1.5576]], device='cuda:0')
# query2: 19it [00:21,  1.15s/it]
# l22: tensor([[1.4548]], device='cuda:0')
# query2: 20it [00:22,  1.12s/it]
# l22: tensor([[1.4630]], device='cuda:0')
# query2: 21it [00:23,  1.10s/it]
# l22: tensor([[1.3560]], device='cuda:0')
# query2: 22it [00:24,  1.09s/it]
# l22: tensor([[1.5910]], device='cuda:0')
# query2: 23it [00:25,  1.08s/it]
# l22: tensor([[1.8194]], device='cuda:0')
# query2: 24it [00:26,  1.08s/it]
# l22: tensor([[1.6522]], device='cuda:0')
# query2: 25it [00:28,  1.08s/it]
# l22: tensor([[1.6854]], device='cuda:0')
# query2: 26it [00:29,  1.13s/it]
# l22: tensor([[1.7338]], device='cuda:0')
# query2: 27it [00:30,  1.27s/it]
# l22: tensor([[2.8073]], device='cuda:0')
# query2: 28it [00:32,  1.24s/it]
# l22: tensor([[1.6492]], device='cuda:0')
# query2: 29it [00:33,  1.19s/it]
# l22: tensor([[1.4453]], device='cuda:0')
# query2: 30it [00:34,  1.15s/it]
# l22: tensor([[2.0916]], device='cuda:0')
# query2: 31it [00:35,  1.17s/it]
# l22: tensor([[2.4484]], device='cuda:0')
# query2: 32it [00:36,  1.17s/it]
# l22: tensor([[1.8232]], device='cuda:0')
# query2: 33it [00:37,  1.16s/it]
# l22: tensor([[1.5629]], device='cuda:0')
# query2: 34it [00:38,  1.13s/it]
# l22: tensor([[1.6023]], device='cuda:0')
# query2: 35it [00:39,  1.13s/it]
# l22: tensor([[4.1783]], device='cuda:0')
# query2: 36it [00:40,  1.12s/it]
# l22: tensor([[1.5439]], device='cuda:0')
# query2: 37it [00:42,  1.23s/it]
# l22: tensor([[1.5076]], device='cuda:0')
# query2: 38it [00:43,  1.30s/it]
# l22: tensor([[1.4873]], device='cuda:0')
# query2: 39it [00:45,  1.24s/it]
# l22: tensor([[1.8361]], device='cuda:0')
# query2: 40it [00:46,  1.19s/it]
# l22: tensor([[1.9966]], device='cuda:0')
# query2: 41it [00:47,  1.15s/it]
# l22: tensor([[1.4294]], device='cuda:0')
# query2: 42it [00:48,  1.14s/it]
# l22: tensor([[1.5022]], device='cuda:0')
# query2: 43it [00:49,  1.14s/it]
# l22: tensor([[1.4644]], device='cuda:0')
# query2: 44it [00:50,  1.14s/it]
# l22: tensor([[1.6172]], device='cuda:0')
# query2: 45it [00:51,  1.13s/it]
# l22: tensor([[1.6946]], device='cuda:0')
# query2: 46it [00:52,  1.13s/it]
# l22: tensor([[1.6476]], device='cuda:0')
# query2: 47it [00:54,  1.19s/it]
# l22: tensor([[1.4230]], device='cuda:0')
# query2: 48it [00:55,  1.28s/it]
# l22: tensor([[1.8343]], device='cuda:0')
# query2: 49it [00:56,  1.23s/it]
# l22: tensor([[1.5006]], device='cuda:0')
# query2: 50it [00:57,  1.19s/it]
# l22: tensor([[1.4802]], device='cuda:0')
# query2: 51it [00:58,  1.15s/it]
# l22: tensor([[1.3168]], device='cuda:0')
# query2: 52it [00:59,  1.13s/it]
# l22: tensor([[1.5026]], device='cuda:0')
# query2: 53it [01:01,  1.12s/it]
# l22: tensor([[1.4740]], device='cuda:0')
# query2: 54it [01:02,  1.11s/it]
# l22: tensor([[3.4041]], device='cuda:0')
# query2: 55it [01:03,  1.09s/it]
# l22: tensor([[1.4216]], device='cuda:0')
# query2: 56it [01:04,  1.10s/it]
# l22: tensor([[3.7549]], device='cuda:0')
# query2: 57it [01:05,  1.10s/it]
# l22: tensor([[1.3328]], device='cuda:0')
# query2: 58it [01:06,  1.22s/it]
# l22: tensor([[1.6339]], device='cuda:0')
# query2: 59it [01:08,  1.23s/it]
# l22: tensor([[1.4819]], device='cuda:0')
# query2: 60it [01:09,  1.19s/it]
# l22: tensor([[1.4964]], device='cuda:0')
# query2: 61it [01:10,  1.16s/it]
# l22: tensor([[1.6404]], device='cuda:0')
# query2: 62it [01:11,  1.13s/it]
# l22: tensor([[1.7166]], device='cuda:0')
# query2: 63it [01:12,  1.12s/it]
# l22: tensor([[1.5089]], device='cuda:0')
# query2: 64it [01:13,  1.10s/it]
# l22: tensor([[2.5369]], device='cuda:0')
# query2: 65it [01:14,  1.09s/it]
# l22: tensor([[1.5428]], device='cuda:0')
# query2: 66it [01:15,  1.09s/it]
# l22: tensor([[1.4862]], device='cuda:0')
# query2: 67it [01:16,  1.08s/it]
# l22: tensor([[1.7344]], device='cuda:0')
# query2: 68it [01:18,  1.13s/it]
# l22: tensor([[1.4265]], device='cuda:0')
# query2: 69it [01:19,  1.25s/it]
# l22: tensor([[1.4538]], device='cuda:0')
# query2: 70it [01:20,  1.20s/it]
# l22: tensor([[3.7301]], device='cuda:0')
# query2: 71it [01:21,  1.16s/it]
# l22: tensor([[1.4713]], device='cuda:0')
# query2: 72it [01:22,  1.14s/it]
# l22: tensor([[1.3665]], device='cuda:0')
# query2: 73it [01:23,  1.12s/it]
# l22: tensor([[1.4732]], device='cuda:0')
# query2: 74it [01:24,  1.10s/it]
# l22: tensor([[1.3919]], device='cuda:0')
# query2: 75it [01:26,  1.09s/it]
# l22: tensor([[1.9497]], device='cuda:0')
# query2: 76it [01:27,  1.08s/it]
# l22: tensor([[1.2824]], device='cuda:0')
# query2: 77it [01:28,  1.08s/it]
# l22: tensor([[1.5012]], device='cuda:0')
# query2: 78it [01:29,  1.08s/it]
# l22: tensor([[1.9456]], device='cuda:0')
# query2: 79it [01:30,  1.19s/it]
# l22: tensor([[1.3901]], device='cuda:0')
# query2: 80it [01:32,  1.24s/it]
# l22: tensor([[1.8095]], device='cuda:0')
# query2: 81it [01:33,  1.19s/it]
# l22: tensor([[1.5584]], device='cuda:0')
# query2: 82it [01:34,  1.16s/it]
# l22: tensor([[1.7728]], device='cuda:0')
# query2: 83it [01:35,  1.14s/it]
# l22: tensor([[1.5286]], device='cuda:0')
# query2: 84it [01:36,  1.12s/it]
# l22: tensor([[1.5142]], device='cuda:0')
# query2: 85it [01:37,  1.10s/it]
# l22: tensor([[1.5281]], device='cuda:0')
# query2: 86it [01:38,  1.09s/it]
# l22: tensor([[1.5860]], device='cuda:0')
# query2: 87it [01:39,  1.08s/it]
# l22: tensor([[1.9008]], device='cuda:0')
# query2: 88it [01:40,  1.08s/it]
# l22: tensor([[1.5651]], device='cuda:0')
# query2: 89it [01:41,  1.10s/it]
# l22: tensor([[2.8384]], device='cuda:0')
# query2: 90it [01:43,  1.23s/it]
# l22: tensor([[1.5395]], device='cuda:0')
# query2: 91it [01:44,  1.22s/it]
# l22: tensor([[1.9295]], device='cuda:0')
# query2: 92it [01:45,  1.18s/it]
# l22: tensor([[4.0855]], device='cuda:0')
# query2: 93it [01:46,  1.15s/it]
# l22: tensor([[1.9899]], device='cuda:0')
# query2: 94it [01:47,  1.12s/it]
# l22: tensor([[3.6907]], device='cuda:0')
# query2: 95it [01:48,  1.11s/it]
# l22: tensor([[2.1324]], device='cuda:0')
# query2: 96it [01:49,  1.09s/it]
# l22: tensor([[1.5749]], device='cuda:0')
# query2: 97it [01:50,  1.08s/it]
# l22: tensor([[1.4073]], device='cuda:0')
# query2: 98it [01:51,  1.08s/it]
# l22: tensor([[1.4871]], device='cuda:0')
# query2: 99it [01:53,  1.08s/it]
# l22: tensor([[2.4499]], device='cuda:0')
# query2: 100it [01:54,  1.14s/it]
# l22: tensor([[2.2930]], device='cuda:0')

# %%
# Threshold2 보다 크면 이상치로 판별 (두 번째 모델)
data2 = anomaly_score2
data2 = [idx2 for idx2, d2 in enumerate(data2) if d2 > Threshold2]
outliers_idx2 = data2
print(outliers_idx2)
# Out:
# [9, 26, 29, 30, 34, 53, 55, 63, 69, 88, 91, 93, 94, 98, 99]

# %% [markdown]
# 모델의 정확도 계산

# %%
count = 0 #맞은 개수
fault = [] #틀린 것 인덱스
test_label = pd.read_csv('/content/data/open/test.csv')['label'].tolist()

for idx in range(len(test_label)):
  tr = 1 if (anomaly_score[idx] > Threshold or anomaly_score2[idx] > Threshold2) else 0
  if tr == test_label[idx]:
    count += 1
  else:
    fault.append(idx)

accuracy = count / len(test_label) #정확도
print(accuracy)
print(fault)
# Out:
# 0.99
# [83]
